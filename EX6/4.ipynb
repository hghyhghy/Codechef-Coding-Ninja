# %%
import numpy as np 
import matplotlib.pyplot as plt

ypoint  = np.array([3,8,1,10])

plt.plot(ypoint, marker="o", ms=15,mfc="r", mec="r")

plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 

ypoint = np.array([3,8,1,10])

plt.plot(ypoint, linestyle = "dotted")

plt.show()
