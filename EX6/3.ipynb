# %%
import numpy as np
import matplotlib.pyplot as plt 

# marker edged color 

ypoint =  np.array([3,8,1,10])

plt.plot(ypoint,marker="o",mec= "r")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 

# set the inside color of the marker 

ypoint  = np.array([3,8,1,10])

plt.plot(ypoint, marker="o", ms=10, mfc="r")

plt.show()
